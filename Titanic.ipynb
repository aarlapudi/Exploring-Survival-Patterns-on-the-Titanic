# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\nithi\Downloads\titanic\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated(subset = "Sex")
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
df.duplicated(subset = "Age")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df["Name"].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
pd.set_option('display.max_rows',88)

# %%
df["Age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 35.00    18
# 27.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 34.00    15
# 33.00    15
# 23.00    15
# 39.00    14
# 40.00    13
# 17.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 44.00     9
# 48.00     9
# 47.00     9
# 54.00     8
# 9.00      8
# 1.00      7
# 51.00     7
# 14.00     6
# 52.00     6
# 37.00     6
# 49.00     6
# 41.00     6
# 3.00      6
# 58.00     5
# 15.00     5
# 43.00     5
# 62.00     4
# 56.00     4
# 5.00      4
# 11.00     4
# 60.00     4
# 8.00      4
# 6.00      3
# 46.00     3
# 61.00     3
# 65.00     3
# 7.00      3
# 10.00     2
# 64.00     2
# 13.00     2
# 63.00     2
# 30.50     2
# 57.00     2
# 70.00     2
# 0.75      2
# 71.00     2
# 59.00     2
# 0.83      2
# 40.50     2
# 55.00     2
# 32.50     2
# 28.50     2
# ...

# %%
df["Name"].value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
# We have 177 null values in age column. Now  using median  we are going to fill the null values.
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Now im going to drop cabin column because it has 687 null values which is more than 75% and by droping the column it doesn't 
# effect the outcome or EDA 

df.drop('Cabin', axis = 1, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Ticket'].value_counts()
pd.set_option('display.max_rows', 890)
df['Ticket'].value_counts()
# Out:
# 347082                7
# CA. 2343              7
# 1601                  7
# 3101295               6
# CA 2144               6
# 347088                6
# S.O.C. 14879          5
# 382652                5
# LINE                  4
# PC 17757              4
# 17421                 4
# 349909                4
# 113760                4
# 4133                  4
# 113781                4
# W./C. 6608            4
# 2666                  4
# 19950                 4
# 347077                4
# C.A. 31921            3
# PC 17572              3
# C.A. 34651            3
# 363291                3
# F.C.C. 13529          3
# 345773                3
# 248727                3
# 24160                 3
# 29106                 3
# SC/Paris 2123         3
# 35273                 3
# 371110                3
# 230080                3
# PC 17760              3
# 239853                3
# PC 17582              3
# 347742                3
# 110152                3
# 13502                 3
# ...

# %%
# You can create a Ticket_GroupSize feature instead, which is much more meaningful for survival analysis.
# Do passengers in groups have higher survival rates?
# This usually shows families/groups survived more than solo travelers.

ticket_counts = df['Ticket'].value_counts()
df['Ticket_GroupSize'] = df['Ticket'].map(ticket_counts)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PassengerId       891 non-null    int64
#  1   Survived          891 non-null    int64
#  2   Pclass            891 non-null    int64
#  3   Name              891 non-null    object
#  4   Sex               891 non-null    object
#  5   Age               891 non-null    float64
#  6   SibSp             891 non-null    int64
#  7   Parch             891 non-null    int64
#  8   Ticket            891 non-null    object
#  9   Fare              891 non-null    float64
#  10  Embarked          889 non-null    object
#  11  Ticket_GroupSize  891 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
df.nunique()
# Out:
# PassengerId         891
# Survived              2
# Pclass                3
# Name                891
# Sex                   2
# Age                  88
# SibSp                 7
# Parch                 7
# Ticket              681
# Fare                248
# Embarked              3
# Ticket_GroupSize      7
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Pairplot

# %%
numeric_cols = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Ticket_GroupSize']


sns.pairplot(df[numeric_cols + ['Survived']], 
             hue='Survived',        # Color by Survived
             diag_kind='hist',      # Histogram on diagonal
             palette='Set1')       # Color palette        
plt.suptitle("Pairplot of Numeric Features by Survival", y=1.02)
plt.show()

# %% [markdown]
# # Heatmap

# %%
numeric_cols = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Ticket_GroupSize']

# Compute correlation matrix
corr_matrix = df[numeric_cols + ['Survived']].corr()

# Plot heatmap
plt.figure(figsize=(10,6))  # Figure size
sns.heatmap(corr_matrix, 
            annot=True,        # Show correlation values on each cell
            cmap='coolwarm',   # Color map: red = positive, blue = negative
            fmt=".2f")         # Format correlation values to 2 decimal places
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %% [markdown]
# # Histogram Plots

# %%
# Age distribution

plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution of Passengers")
plt.show()

# %%
# Pclass distribution
plt.figure(figsize = (8,5))
sns.histplot(df['Pclass'], bins = 20, kde = True)
plt.title('Pclass distribution of passengers')
plt.show()

# %%
# Fare distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Fare'], bins=10, kde=True)
plt.title("Fare Distribution of Passengers")
plt.show()

# %%
# Ticket group size distribution
plt.figure(figsize=(8,5))
sns.histplot(df['Ticket_GroupSize'], bins=15, kde=False)
plt.title("Ticket Group Size Distribution")
plt.show()

# %% [markdown]
# # Box plot

# %%
# Age by Survival
plt.figure(figsize=(8,5))
sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age Distribution by Survival")
plt.show()

# %%
# Fare by Survival
plt.figure(figsize=(8,5))
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title("Fare Distribution by Survival")
plt.show()

# %%
# Fare by Pclass
plt.figure(figsize=(8,5))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title("Fare Distribution by Passenger Class")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
# Fare vs Age, colored by survival
plt.figure(figsize=(8,5))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df, alpha=1)
plt.title("Fare vs Age by Survival")
plt.show()

# %%
# Ticket Group Size vs Fare, colored by survival
plt.figure(figsize=(8,5))
sns.scatterplot(x='Ticket_GroupSize', y='Fare', hue='Survived', data=df, alpha=0.7)
plt.title("Ticket Group Size vs Fare by Survival")
plt.show()
